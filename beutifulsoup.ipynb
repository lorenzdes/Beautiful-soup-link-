# %%
from bs4 import BeautifulSoup
import urllib

# %%
import urllib.request
link = r'https://datareportal.com/reports/digital-2022-italy'
f = urllib.request.urlopen(link)
myfile = f.read()
#txt
print(myfile)
soup = BeautifulSoup(myfile)
# Soup for elboration whole webpage in html
soup
# Out:
# b'<!doctype html>\n<html xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml" lang="en-GB"  >\n  <head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="viewport" content="initial-scale=1">\n\n    <!-- This is Squarespace. --><!-- papaya-avocado-9tgy -->\n<base href="">\n<meta charset="utf-8" />\n<title>Digital 2022: Italy &mdash; DataReportal \xe2\x80\x93 Global Digital Insights</title>\n<meta http-equiv="Accept-CH" content="Sec-CH-UA-Platform-Version, Sec-CH-UA-Model" /><link rel="shortcut icon" type="image/x-icon" href="https://images.squarespace-cdn.com/content/v1/5b79011d266c077298791201/b9aaa33f-e650-4dea-8cb6-9d7bc9bb5c4f/favicon.ico?format=100w"/>\n<link rel="canonical" href="https://datareportal.com/reports/digital-2022-italy"/>\n<meta property="og:site_name" content="DataReportal \xe2\x80\x93 Global Digital Insights"/>\n<meta property="og:title" content="Digital 2022: Italy &mdash; DataReportal \xe2
# ...

# %%
# Title of article
title = soup.find('title').string
print(title)
# Out:
# Digital 2022: Italy — DataReportal – Global Digital Insights

# %%
# Clickable url
url = soup.find("meta", property="og:url")
print(url["content"] if url else "No meta url given")
# Out:
# https://datareportal.com/reports/digital-2022-italy

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="initial-scale=1" name="viewport"/>
# <!-- This is Squarespace. --><!-- papaya-avocado-9tgy -->
# <base href=""/>
# <meta charset="utf-8"/>
# <title>Digital 2022: Italy — DataReportal – Global Digital Insights</title>
# <meta content="Sec-CH-UA-Platform-Version, Sec-CH-UA-Model" http-equiv="Accept-CH"/><link href="https://images.squarespace-cdn.com/content/v1/5b79011d266c077298791201/b9aaa33f-e650-4dea-8cb6-9d7bc9bb5c4f/favicon.ico?format=100w" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://datareportal.com/reports/digital-2022-italy" rel="canonical"/>
# <meta content="DataReportal – Global Digital Insights" property="og:site_name"/>
# <meta content="Digital 2022: Italy — DataReportal – Global Digital Insights" property="og:title"/>
# ...

# %%
header = soup.find('meta', attrs={'itemprop': 'description'})
header
# Out:
# <meta content="All the data, insights, and trends you need to help you make sense of the “state of digital” in Italy in 2022, including detailed statistics for internet use, social media use, and mobile use, as well as user numbers for all the top social platforms." itemprop="description"/>

# %%
corpus = soup.find('meta', attrs={'name': 'description'})
corpus
# Out:
# <meta content="All the data, insights, and trends you need to help you make sense of the
# “state of digital” in Italy in 2022, including detailed statistics for
# internet use, social media use, and mobile use, as well as user numbers for
# all the top social platforms." name="description"/>

# %%
td = soup.find('p').find('b') #<b>Address:</b>
td.contents
# Out:
# ['Italy']
